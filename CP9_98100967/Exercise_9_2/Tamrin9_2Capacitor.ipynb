# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("dark_background")

# %%
def q_dot(q, C=1, V=1, R=1):
    return (C*V - q)/(R*C)


def class_algorithm(q0, f, h, time):
    ys = np.zeros(len(time)+1)
    ys[0] = q0
    for i in range(len(ys)-1):
        ys[i+1] = ys[i-1] + 2 * h * f(ys[i])
    return ys


def analytical_solution(t, C=1, V=1, R=1):
    return C*V * (1 - np.exp(-t/(R*C)))

# %%
# Reduced Constants:
R = 1
C = 1
V = 1
# Initial Value of the Charge on the Capacitor:
q0 = 0
h = 0.01
time = np.arange(0, 5, h)
fig, ax = plt.subplots()
ax.plot(analytical_solution(t=time, C=C, V=V, R=R), label="Analytical", lw=5, color="orange", zorder=2)
ax.plot(class_algorithm(q0=q0, f=q_dot, h=h, time=time), "m", label="Numerical", lw=2, zorder=1)
ax.set_title(f"Analytical and Numerical Calculation\nof the Charge on a Capacitor as a Function of Time\nClass Algorithm; h={h}",
             fontsize=10)
ax.set_xlabel("time steps")
ax.set_ylabel("Capacitor Charge $q(t)$")
ax.legend();

# %%
# fig.savefig("TamrinCapacitor2_h01.jpg")

# %%
# Reduced Constants:
R = 1
C = 1
V = 1
# Initial Value of the Charge on the Capacitor:
q0 = 0
h = 0.001
time = np.arange(0, 5, h)
fig, ax = plt.subplots()
ax.plot(analytical_solution(t=time, C=C, V=V, R=R), label="Analytical", lw=5, color="orange", zorder=2)
ax.plot(class_algorithm(q0=q0, f=q_dot, h=h, time=time), "m", label="Numerical", lw=2, zorder=1)
ax.set_title(f"Analytical and Numerical Calculation\nof the Charge on a Capacitor as a Function of Time\nClass Algorithm; h={h}",
             fontsize=10)
ax.set_xlabel("time steps")
ax.set_ylabel("Capacitor Charge $q(t)$")
ax.legend();

# %%
fig.savefig("TamrinCapacitor2_h001.jpg")

# %%
# Reduced Constants:
R = 1
C = 1
V = 1
# Initial Value of the Charge on the Capacitor:
q0 = 0
h = 0.0001
time = np.arange(0, 8, h)
fig, ax = plt.subplots()
ax.plot(analytical_solution(t=time, C=C, V=V, R=R), label="Analytical", lw=5, color="orange", zorder=2)
ax.plot(class_algorithm(q0=q0, f=q_dot, h=h, time=time), "m", label="Numerical", lw=2, zorder=1)
ax.set_title(f"Analytical and Numerical Calculation\nof the Charge on a Capacitor as a Function of Time\nClass Algorithm; h={h}",
             fontsize=10)
ax.set_xlabel("time steps")
ax.set_ylabel("Capacitor Charge $q(t)$")
ax.legend();

# %%
# fig.savefig("TamrinCapacitor2_h0001.jpg")

# %%
# This cell takes 19 seconds to execute:
num_samples = 20
hs = np.logspace(-7, -5, num_samples)
error = np.zeros(num_samples)
for i in range(num_samples):
    time = np.arange(0, 0.5, hs[i])
    error[i] = np.abs(analytical_solution(t=time)[-1] - class_algorithm(q0=0, f=q_dot, h=hs[i], time=time)[-1])

# %%
fig, ax = plt.subplots()

# ax.scatter(x=hs, y=error, c="orange", s=5, linestyle="--")
ax.plot(hs, error, color="m", linestyle="--", marker="o")
ax.set_title("Error of Numerical Calculation for Different Values of h\nClass Algorithm\nSimulation Time: 0.5 seconds",
             fontsize=10)
ax.set_xlabel("h")
ax.set_ylabel("Error (Difference with Analytical Solution)");

# %%
# fig.savefig("TamrinCapacitor2_Error.jpg")
